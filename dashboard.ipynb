# %% [markdown]
# # Africa population and internet penetration

# %% [markdown]
# Building an interactive dashboard using ipywidgets

# %%
import ipywidgets as widgets
from IPython.display import display
from ipywidgets.widgets import interact
import matplotlib.pyplot as plt
from matplotlib.ticker import FuncFormatter
import numpy as np
import pandas as pd

# %matplotlib inline

# %%
africa = pd.read_csv('africa.csv')

# %%
def convert_to_int(num_str):
    return int("".join(num_str.split(',')))

# %%
africa.population = africa.population.apply(lambda x: convert_to_int(x))
africa.internet_users = africa.internet_users.apply(lambda x: convert_to_int(x))

# %%
# Create a piechart function
def country_internet_stats(country):
    """
    Create a piechart of a country's internet penetration
    """
    country_data = africa[africa.country==country]
    
    connected = country_data['internet_users'].item()
    
    population = country_data['population'].item()
    not_connected = population - connected

    labels = ['Connected', 'Not Connected']
    sizes = [connected, not_connected]
    explode = (0, 0.1)  # only "explode" the 2nd slice

    fig1, ax1 = plt.subplots()
    ax1.pie(sizes, explode=explode, labels=labels, autopct='%1.1f%%', shadow=True, startangle=90)
    ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

    plt.show()

# %%
# Creating the dropdown widget for countries
country_dropdown = widgets.Dropdown(
    options=list(africa.country.unique()),
    description='Country:',
    disabled=False,
)

# %%
def country_by_population(pop):
    """
    Create a bar chart that display the countries above a specified population
    @params pop (population)
    """
    pop_dis = africa[africa.population>=pop]

    x = np.arange(africa[africa.population>pop].shape[0])
    fig = plt.figure(figsize=(15,5))
    plt.bar(x, pop_dis.population)
    plt.xticks(x, list(pop_dis.country), rotation='vertical')
    plt.show()

# %%
# Population slider
pop_slider = widgets.IntSlider(
                    value=10000000,
                    min=0,
                    max=africa.population.max(),
                    step=1000,
                    description='Population',
                    disabled=False,
                    continuous_update=False,
                    orientation='horizontal',
                    readout=True,
                    readout_format='d'
                )

# %% [markdown]
# # Dashboard

# %% [markdown]
# #### A piechart showing the percentage of internet user by country

# %%
internet_interaction = interact(
    country_internet_stats,
    country = country_dropdown
)
# Out:
# interactive(children=(Dropdown(description='Country:', options=('Algeria', 'Angola', 'Benin', 'Botswana', 'Bur…

# %%
pop_interact = interact(
    country_by_population,
    pop = pop_slider
)
# Out:
# interactive(children=(IntSlider(value=10000000, continuous_update=False, description='Population', max=1958752…

# %%
africa
# Out:
#                  country   population internet_users
# 0                Algeria   42,008,054     18,580,000
# 1                 Angola   30,774,205      5,951,453
# 2                  Benin   11,458,674      3,801,758
# 3               Botswana    2,333,201        923,528
# 4           Burkina Faso   19,751,651      3,704,265
# 5                Burundi   11,216,450        617,116
# 6           Cabo\n Verde      553,335        265,972
# 7               Cameroon   24,678,234      6,128,422
# 8   Central African Rep.    4,737,423        256,432
# 9                   Chad   15,353,184        768,274
# 10               Comoros      832,347        130,578
# 11                 Congo    5,399,895        650,000
# 12    Congo,\n Dem. Rep.   84,004,989      5,137,271
# 13       Cote\n d'Ivoire   24,905,843      6,318,355
# 14              Djibouti      971,408        180,000
# 15                 Egypt   99,375,741     49,231,493
# 16     Equatorial Guinea    1,313,894        312,704
# 17               Eritrea    5,187,948         71,000
# 18              Ethiopia  107,534,882     16,437,811
# 19                 Gabon    2,067,561        985,492
# 20                Gambia    2,163,765        392,277
# 21                 Ghana   29,463,643     10,110,000
# 22                Guinea   13,052,608      1,602,485
# 23         Guinea-Bissau    1,907,268        120,000
# 24                 Kenya   50,950,879     43,329,434
# 25               Lesotho    2,263,010        627,860
# 26               Liberia    4,853,516        395,063
# 27                 Libya    6,470,956      3,800,000
# 28            Madagascar   26,262,810      1,900,000
# 29                Malawi   19,164,728      1,828,503
# 30                  Mali   19,107,706     12,480,176
# 31            Mauritania    4,540,068        810,000
# 32             Mauritius    1,268,315        803,896
# 33          Mayotte (FR)      259,682        107,940
# 34               Morocco   36,191,805     22,567,154
# 35            Mozambique   30,528,673      5,279,135
# 36               Namibia    2,587,801        797,027
# 37                 Niger   22,311,375        951,548
# 38               Nigeria  195,875,237     98,391,456
# 39          Reunion (FR)      883,247        480,000
# 40                Rwanda   12,501,156      3,724,678
# 41   Saint\n Helena (UK)        4,049          2,200
# 42  Sao\nTome & Principe      208,818         57,875
# 43               Senegal   16,294,270      9,749,527
# 44            Seychelles       95,235         67,119
# 45        Sierra\n Leone    7,719,729        902,462
# 46               Somalia   15,181,925      1,200,000
# 47        South\n Africa   57,398,421     30,815,634
# 48           South Sudan   12,919,053      2,229,963
# 49                 Sudan   41,511,526     11,816,570
# 50             Swaziland    1,391,385        446,051
# 51              Tanzania   59,091,392     23,000,000
# 52                  Togo    7,990,926        899,956
# 53               Tunisia   11,659,174      7,898,534
# 54                Uganda   44,270,563     19,000,000
# 55        Western Sahara      561,257         28,000
# 56                Zambia   17,609,178      7,248,773
# 57              Zimbabwe   16,913,261      6,796,314
